# %% [markdown]
# # Video Game Stats
# ## Tim Schoen 3/11/19

# %%
import numpy as np

# %%
import pandas as pd

# %%
pd
# Out:
# <module 'pandas' from '/Users/schoentr/.local/share/virtualenvs/data_analysis-_inod1he/lib/python3.7/site-packages/pandas/__init__.py'>

# %%
games_frame = pd.read_csv('vgsales.csv')

# %%
games_frame[:5]
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
games_frame['Publisher'].describe()
# Out:
# count               16540
# unique                578
# top       Electronic Arts
# freq                 1351
# Name: Publisher, dtype: object

# %%
games_frame['Platform'].describe()
# Out:
# count     16598
# unique       31
# top          DS
# freq       2163
# Name: Platform, dtype: object

# %%
games_frame['Genre'].describe()
# Out:
# count      16598
# unique        12
# top       Action
# freq        3316
# Name: Genre, dtype: object

# %%
games_frame.nlargest(20,'Global_Sales')
# Out:
#     Rank                                          Name Platform    Year  \
# 0      1                                    Wii Sports      Wii  2006.0
# 1      2                             Super Mario Bros.      NES  1985.0
# 2      3                                Mario Kart Wii      Wii  2008.0
# 3      4                             Wii Sports Resort      Wii  2009.0
# 4      5                      Pokemon Red/Pokemon Blue       GB  1996.0
# 5      6                                        Tetris       GB  1989.0
# 6      7                         New Super Mario Bros.       DS  2006.0
# 7      8                                      Wii Play      Wii  2006.0
# 8      9                     New Super Mario Bros. Wii      Wii  2009.0
# 9     10                                     Duck Hunt      NES  1984.0
# 10    11                                    Nintendogs       DS  2005.0
# 11    12                                 Mario Kart DS       DS  2005.0
# ...

# %%
games_frame['NA_Sales'].median()
# Out:
# 0.08

# %%
games_frame[games_frame['NA_Sales'] == .08].sample(n=10)[['Name','NA_Sales']]
# Out:
#                                        Name  NA_Sales
# 3186                         SingStar Queen      0.08
# 11316            Major League Baseball 2K12      0.08
# 10641                    Milo's Astro Lanes      0.08
# 8724                                 Driven      0.08
# 11156               Jumper: Griffin's Story      0.08
# 10676  Alvin and the Chipmunks: Chipwrecked      0.08
# 8563       Namco Classic Fighter Collection      0.08
# 11357                     Puchi Puchi Virus      0.08
# 3921                   Test Drive Unlimited      0.08
# 11235                     Petz: Saddle Club      0.08

# %% [markdown]
# * For the top-selling game of all time, how many standard deviations above/below the mean are its sales for North America?

# %%
games_frame.std().NA_Sales
# Out:
# 0.8166830292988796

# %% [markdown]
# * The Nintendo Wii seems to have outdone itself with games. How does its average number of sales compare with all of the other platforms?
